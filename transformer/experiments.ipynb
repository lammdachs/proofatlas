# %%
import os 
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from . import *
#
# ImportError: attempted relative import with no known parent package

# %%
datamodule = IntegerSortingDataModule()

# %%
datamodule.setup()

# %%
datamodule.train_dataloader().__iter__().__next__()
# Out:
# [tensor([[1, 3, 0, 3, 5, 2, 2, 6, 2, 9, 0, 1, 2, 2, 2, 3, 3, 5, 6],
#          [9, 2, 4, 8, 4, 9, 8, 7, 6, 5, 2, 4, 4, 5, 6, 7, 8, 8, 9],
#          [1, 6, 6, 4, 2, 5, 4, 6, 1, 5, 1, 1, 2, 4, 4, 5, 5, 6, 6],
#          [7, 7, 3, 6, 7, 8, 4, 8, 8, 0, 0, 3, 4, 6, 7, 7, 7, 8, 8],
#          [5, 7, 5, 5, 1, 2, 8, 3, 1, 9, 1, 1, 2, 3, 5, 5, 5, 7, 8],
#          [1, 4, 9, 5, 0, 8, 9, 5, 2, 3, 0, 1, 2, 3, 4, 5, 5, 8, 9],
#          [1, 0, 9, 5, 6, 8, 1, 2, 2, 4, 0, 1, 1, 2, 2, 4, 5, 6, 8],
#          [2, 5, 8, 1, 2, 9, 2, 9, 2, 3, 1, 2, 2, 2, 2, 3, 5, 8, 9],
#          [1, 3, 6, 7, 9, 9, 1, 0, 2, 1, 0, 1, 1, 1, 2, 3, 6, 7, 9],
#          [8, 9, 6, 5, 0, 4, 6, 6, 4, 1, 0, 1, 4, 4, 5, 6, 6, 6, 8],
#          [6, 2, 2, 9, 3, 2, 4, 4, 5, 8, 2, 2, 2, 3, 4, 4, 5, 6, 8],
#          [3, 3, 3, 0, 5, 5, 9, 2, 1, 6, 0, 1, 2, 3, 3, 3, 5, 5, 6],
#          [2, 6, 3, 9, 9, 8, 4, 4, 2, 4, 2, 2, 3, 4, 4, 4, 6, 8, 9],
#          [4, 7, 5, 8, 7, 7, 9, 3, 9, 7, 3, 4, 5, 7, 7, 7, 7, 8, 9],
# ...
